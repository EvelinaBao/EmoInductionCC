# %%
pip install pingouin
# Out:
# Requirement already satisfied: pingouin in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.5.4)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pingouin) (1.26.4)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pingouin) (1.13.1)
# Requirement already satisfied: pandas>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pingouin) (2.2.2)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pingouin) (3.9.0)
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pingouin) (0.13.2)
# Requirement already satisfied: statsmodels in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pingouin) (0.14.2)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pingouin) (1.5.1)
# Requirement already satisfied: pandas-flavor in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pingouin) (0.6.0)
# Requirement already satisfied: tabulate in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pingouin) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.5->pingouin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.5->pingouin) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.5->pingouin) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->pingouin) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->pingouin) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->pingouin) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->pingouin) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->pingouin) (23.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->pingouin) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->pingouin) (3.1.2)
# Requirement already satisfied: xarray in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas-flavor->pingouin) (2024.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn->pingouin) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn->pingouin) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from statsmodels->pingouin) (0.5.6)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels->pingouin) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
from statsmodels.stats import anova
import pingouin as pg
from scipy.stats import levene
import numpy as np
import statsmodels.api as sm
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import OLSInfluence
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices
from sklearn import linear_model
import statsmodels.stats.api as sms
from statsmodels.compat import lzip
from scipy.stats import bartlett
from statsmodels.stats import diagnostic as diag
from patsy.contrasts import Sum
import statsmodels.genmod.families.links as links
from statsmodels.stats.mediation import Mediation
from statsmodels.formula.api import mixedlm
import patsy

# %%
df = pd.read_csv('/Users/evelinabao/Documents/COCO Lab/Balanced Emotion Intervention/Replication/Data/Final_Data_Cleaned.csv')
df
# Out:
#       Duration__in_seconds_        RecordedDate  Climate_Pre_1  \
# 0                       862  6/27/2025 14:39:08             60
# 1                      1449  6/24/2025 13:51:29             61
# 2                      2765  6/24/2025 14:14:49             10
# 3                       644  6/27/2025 15:32:03             97
# 4                      2186  6/24/2025 14:06:36            100
# ...                     ...                 ...            ...
# 1440                   3834  6/24/2025 14:34:20             85
# 1441                   1875  6/24/2025 14:01:59             73
# 1442                   1613  6/24/2025 13:54:54            100
# 1443                   1408  6/24/2025 13:51:31             39
# 1444                   2018  6/24/2025 14:03:57             94
#
#       Vaccination_Pre_1  Education_Pre_1  GayRight_Pre_1  \
# 0                   100              100             100
# 1                    69               77              43
# 2                   100              100             100
# 3                    96               96              34
# 4                    80               99              29
# ...                 ...              ...             ...
# 1440                 73               74              88
# 1441                 60               95              92
# 1442                 96              100              19
# 1443                 74               60              44
# 1444                 76               93              91
#
#                            PID  AC_1 Q135_First_Click Q135_Last_Click  ...  \
# 0     55678ac4fdf99b02081d82c2     2                0               0  ...
# 1     558ab509fdf99b65685f024e     2                                   ...
# 2     559e6830fdf99b4f0b98514a     2                                   ...
# 3     5622e4dced6e5a0005c80078     2            5.168           5.168  ...
# 4     56a914f0119265000c6e13c5     2                                   ...
# ...                        ...   ...              ...             ...  ...
# 1440  6859256718199e0cea7e7b19     2                                   ...
# 1441  68594584e4372d120a64a324     2                                   ...
# 1442  68594b34da4fce25502d19bc     2                                   ...
# 1443  6859aa42284ad9606d1d2f72     2                                   ...
# 1444  685a00c2226d8ace12b4883b     2                                   ...
#
#      believer_81 believer_70 believer_50 Knowledge PostBelief    Support  \
# 0              0           0           1         4  50.000000  78.333333
# 1              0           0           1         4  62.000000  73.333333
# 2              0           0           0         6  10.000000  50.000000
# 3              1           1           1         6  81.333333  83.000000
# 4              1           1           1         6  92.000000  80.333333
# ...          ...         ...         ...       ...        ...        ...
# 1440           1           1           1         7  95.000000  97.666667
# 1441           0           1           1         7  81.000000  70.333333
# 1442           1           1           1         5  98.666667  94.666667
# 1443           0           0           0         4  45.000000  56.333333
# 1444           1           1           1         6  82.666667  82.333333
#
#      PEfficacy CEfficacy Efficacy  Intention
# 0         21.0      60.0    40.50  33.333333
# 1         83.0      76.5    79.75  66.666667
# 2         42.5      42.5    42.50  30.000000
# 3         29.0      59.5    44.25  62.166667
# 4         61.5      65.0    63.25  53.000000
# ...        ...       ...      ...        ...
# 1440      96.0     100.0    98.00  97.666667
# 1441      73.0      81.5    77.25  77.500000
# 1442      99.5      96.5    98.00  95.333333
# 1443      68.5      55.5    62.00  55.166667
# 1444      50.0      71.5    60.75  89.166667
#
# [1445 rows x 223 columns]

# %%
#correct datatype

df['strict_attention'] = pd.to_numeric(df['strict_attention'], errors='coerce')

# %%
# import libraries for logistic regression

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.genmod.generalized_linear_model import families
from patsy import dmatrices
from statsmodels.discrete.discrete_model import MNLogit

# %%
# Recode behavioral intentions to 1s and 0s
df['Politics'] = df['Politics'].map({1: 0, 2: 1, 3: 2})

# %% [markdown]
# # Mixed-level logistic regression model with policy priority choice as the dependent variable

# %%
# convert wide to long format
long_df = df.melt(id_vars=['PROLIFIC_PID', 'Condition'],
                  value_vars=['Policy_choice_1', 'Policy_choice_2', 'Policy_choice_3', 'Policy_choice_4', 'Policy_choice_5'],
                  var_name='Policy_item',
                  value_name='Policy_choice')

long_df.head()
# Out:
#                PROLIFIC_PID  Condition      Policy_item  Policy_choice
# 0  55678ac4fdf99b02081d82c2          0  Policy_choice_1              0
# 1  558ab509fdf99b65685f024e          2  Policy_choice_1              0
# 2  559e6830fdf99b4f0b98514a          1  Policy_choice_1              1
# 3  5622e4dced6e5a0005c80078          0  Policy_choice_1              0
# 4  56a914f0119265000c6e13c5          2  Policy_choice_1              1

# %%
import warnings
warnings.filterwarnings('ignore')

# Load R in Python
# %load_ext rpy2.ipython

# %%
# %R library(lme4)
# %R library(lmerTest)
# %R library(ordinal)
# %R library(EMAtools) #for calculating cohens d
# %R library(effectsize) #for calculating ORs
# %R library(performance)
# Out:
# Loading required package: Matrix
# Attaching package: ‘lmerTest’
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
# The following object is masked from ‘package:stats’:
#
#     step
# In addition: Warning message:
# package ‘effectsize’ was built under R version 4.3.3
# In addition: Warning message:
# package ‘performance’ was built under R version 4.3.3

# %%
long_df.to_csv("long_df.csv", index=False)

# %%
# %R long_df <- read.csv("long_df.csv")
# Out:
#                   PROLIFIC_PID  Condition      Policy_item  Policy_choice
# 1     55678ac4fdf99b02081d82c2          0  Policy_choice_1              0
# 2     558ab509fdf99b65685f024e          2  Policy_choice_1              0
# 3     559e6830fdf99b4f0b98514a          1  Policy_choice_1              1
# 4     5622e4dced6e5a0005c80078          0  Policy_choice_1              0
# 5     56a914f0119265000c6e13c5          2  Policy_choice_1              1
# ...                        ...        ...              ...            ...
# 7221  6859256718199e0cea7e7b19          1  Policy_choice_5              1
# 7222  68594584e4372d120a64a324          2  Policy_choice_5              1
# 7223  68594b34da4fce25502d19bc          2  Policy_choice_5              1
# 7224  6859aa42284ad9606d1d2f72          1  Policy_choice_5              0
# 7225  685a00c2226d8ace12b4883b          2  Policy_choice_5              1
#
# [7225 rows x 4 columns]

# %%
# %Rpush long_df

# %% [markdown]
# Original Condition coding: 0 = 'Control', 1 = 'Consequences', 2 = 'Solutions', 3 = 'Combined'

# %%
# %%R
#
# # GLM: Condition on Policy choice
# model <- glmer(Policy_choice ~ C(Condition) + (1 | PROLIFIC_PID) + (1 | Policy_item),
#                data = long_df, family = binomial)
#
# print(summary(model))
# summary_model <- summary(model)
#
# write.csv(coef(summary(model)), "coef_policy.csv")
#
# cohens_d <- lme.dscore(model, data = long_df, type = "lme4")
# print(cohens_d)
#
# confint_model <- confint(model, method = "Wald")
# print(confint_model)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: Policy_choice ~ C(Condition) + (1 | PROLIFIC_PID) + (1 | Policy_item)
#    Data: long_df
#
#      AIC      BIC   logLik deviance df.resid
#   8844.9   8886.3  -4416.5   8832.9     7219
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7093 -0.7791  0.4069  0.6297  1.8266
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  PROLIFIC_PID (Intercept) 1.4057   1.1856
#  Policy_item  (Intercept) 0.2517   0.5017
# Number of obs: 7225, groups:  PROLIFIC_PID, 1445; Policy_item, 5
#
# Fixed effects:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)     0.3000     0.2392   1.254  0.20978
# C(Condition)1   0.3421     0.1175   2.913  0.00358 **
# C(Condition)2   0.4780     0.1188   4.024 5.72e-05 ***
# C(Condition)3   0.6681     0.1191   5.608 2.05e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) C(Cn)1 C(Cn)2
# C(Conditn)1 -0.244
# C(Conditn)2 -0.241  0.494
# C(Conditn)3 -0.240  0.494  0.489
#                      t   df         d
# C(Condition)1 2.884749 1441 0.1519869
# C(Condition)2 3.891867 1441 0.2050482
# C(Condition)3 5.409001 1441 0.2849804
#                    2.5 %    97.5 %
# .sig01                NA        NA
# .sig02                NA        NA
# (Intercept)   -0.1688399 0.7688897
# C(Condition)1  0.1119049 0.5723702
# C(Condition)2  0.2451923 0.7108543
# C(Condition)3  0.4345676 0.9015485

# %%
#recode the condition to make combined condition as the reference group
long_df['Condition'] = long_df['Condition'].map({0:3, 3:0, 1:1, 2:2})

# %% [markdown]
# 0 = combined
# 1 = consequences
# 2 = solutions
# 3 = control

# %%
long_df.head()
# Out:
#                PROLIFIC_PID  Condition      Policy_item  Policy_choice
# 0  55678ac4fdf99b02081d82c2          3  Policy_choice_1              0
# 1  558ab509fdf99b65685f024e          2  Policy_choice_1              0
# 2  559e6830fdf99b4f0b98514a          1  Policy_choice_1              1
# 3  5622e4dced6e5a0005c80078          3  Policy_choice_1              0
# 4  56a914f0119265000c6e13c5          2  Policy_choice_1              1

# %%
# %Rpush long_df

# %%
# %%R
#
# # check is the consequences/solution condition is significant higher than the combined condition
# model <- glmer(Policy_choice ~ C(Condition) + (1 | PROLIFIC_PID) + (1 | Policy_item),
#                data = long_df, family = binomial)
#
# print(summary(model))
# summary_model <- summary(model)
#
# cohens_d <- lme.dscore(model, data = long_df, type = "lme4")
# print(cohens_d)
#
# confint_model <- confint(model, method = "Wald")
# print(confint_model)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: Policy_choice ~ C(Condition) + (1 | PROLIFIC_PID) + (1 | Policy_item)
#    Data: long_df
#
#      AIC      BIC   logLik deviance df.resid
#   8844.9   8886.3  -4416.5   8832.9     7219
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7093 -0.7791  0.4069  0.6297  1.8266
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  PROLIFIC_PID (Intercept) 1.4057   1.1856
#  Policy_item  (Intercept) 0.2517   0.5017
# Number of obs: 7225, groups:  PROLIFIC_PID, 1445; Policy_item, 5
#
# Fixed effects:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)     0.9681     0.2402   4.030 5.59e-05 ***
# C(Condition)1  -0.3259     0.1191  -2.738  0.00619 **
# C(Condition)2  -0.1900     0.1202  -1.581  0.11390
# C(Condition)3  -0.6681     0.1191  -5.607 2.05e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) C(Cn)1 C(Cn)2
# C(Conditn)1 -0.255
# C(Conditn)2 -0.252  0.507
# C(Conditn)3 -0.257  0.514  0.507
#                       t   df           d
# C(Condition)1 -2.537147 1441 -0.13367297
# C(Condition)2 -1.499349 1441 -0.07899521
# C(Condition)3 -5.409000 1441 -0.28498040
#                    2.5 %      97.5 %
# .sig01                NA          NA
# .sig02                NA          NA
# (Intercept)    0.4972026  1.43894120
# C(Condition)1 -0.5592721 -0.09259828
# C(Condition)2 -0.4256403  0.04556870
# C(Condition)3 -0.9015706 -0.43455421

# %%
#recode the condition to make solution condition as the reference group
long_df['Condition'] = long_df['Condition'].map({3:3, 0:2, 2:0, 1:1})

# %% [markdown]
# 0 = solutions
# 1 = consequences
# 2 = combined
# 3 = control

# %%
long_df.head()
# Out:
#                PROLIFIC_PID  Condition      Policy_item  Policy_choice
# 0  55678ac4fdf99b02081d82c2          3  Policy_choice_1              0
# 1  558ab509fdf99b65685f024e          0  Policy_choice_1              0
# 2  559e6830fdf99b4f0b98514a          1  Policy_choice_1              1
# 3  5622e4dced6e5a0005c80078          3  Policy_choice_1              0
# 4  56a914f0119265000c6e13c5          0  Policy_choice_1              1

# %%
# %Rpush long_df

# %%
# %%R
#
# # check is the combined/consequences is significant higher than the solution condition
# model <- glmer(Policy_choice ~ C(Condition) + (1 | PROLIFIC_PID) + (1 | Policy_item),
#                data = long_df, family = binomial)
#
# print(summary(model))
# summary_model <- summary(model)
#
# cohens_d <- lme.dscore(model, data = long_df, type = "lme4")
# print(cohens_d)
#
# confint_model <- confint(model, method = "Wald")
# print(confint_model)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: Policy_choice ~ C(Condition) + (1 | PROLIFIC_PID) + (1 | Policy_item)
#    Data: long_df
#
#      AIC      BIC   logLik deviance df.resid
#   8844.9   8886.3  -4416.5   8832.9     7219
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7093 -0.7791  0.4069  0.6297  1.8266
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  PROLIFIC_PID (Intercept) 1.4057   1.1856
#  Policy_item  (Intercept) 0.2517   0.5017
# Number of obs: 7225, groups:  PROLIFIC_PID, 1445; Policy_item, 5
#
# Fixed effects:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)     0.7780     0.2400   3.241  0.00119 **
# C(Condition)1  -0.1359     0.1188  -1.144  0.25267
# C(Condition)2   0.1900     0.1202   1.581  0.11385
# C(Condition)3  -0.4780     0.1188  -4.024 5.73e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) C(Cn)1 C(Cn)2
# C(Conditn)1 -0.253
# C(Conditn)2 -0.249  0.504
# C(Conditn)3 -0.255  0.511  0.503
#                       t   df           d
# C(Condition)1 -1.025855 1441 -0.05404856
# C(Condition)2  1.499349 1441  0.07899521
# C(Condition)3 -3.891867 1441 -0.20504821
#                     2.5 %      97.5 %
# .sig01                 NA          NA
# .sig02                 NA          NA
# (Intercept)    0.30758478  1.24847367
# C(Condition)1 -0.36872537  0.09694755
# C(Condition)2 -0.04553777  0.42562292
# C(Condition)3 -0.71086405 -0.24516869

# %% [markdown]
# # Examing the moderating effect of pre-existing climate belief

# %%
#recode the condition to original condition coding, with control as the reference group.
long_df['Condition'] = long_df['Condition'].map({0:2, 1:1, 2:3, 3:0})

# %%
long_df.head()
# Out:
#                PROLIFIC_PID  Condition      Policy_item  Policy_choice
# 0  55678ac4fdf99b02081d82c2          0  Policy_choice_1              0
# 1  558ab509fdf99b65685f024e          2  Policy_choice_1              0
# 2  559e6830fdf99b4f0b98514a          1  Policy_choice_1              1
# 3  5622e4dced6e5a0005c80078          0  Policy_choice_1              0
# 4  56a914f0119265000c6e13c5          2  Policy_choice_1              1

# %%
# convert wide to long format adding pre-exisiting belief
long_df = df.melt(id_vars=['PROLIFIC_PID', 'Condition', 'believer_81'],
                  value_vars=['Policy_choice_1', 'Policy_choice_2', 'Policy_choice_3', 'Policy_choice_4', 'Policy_choice_5'],
                  var_name='Policy_item',
                  value_name='Policy_choice')

long_df.head()
# Out:
#                PROLIFIC_PID  Condition  believer_81      Policy_item  \
# 0  55678ac4fdf99b02081d82c2          0            0  Policy_choice_1
# 1  558ab509fdf99b65685f024e          2            0  Policy_choice_1
# 2  559e6830fdf99b4f0b98514a          1            0  Policy_choice_1
# 3  5622e4dced6e5a0005c80078          0            1  Policy_choice_1
# 4  56a914f0119265000c6e13c5          2            1  Policy_choice_1
#
#    Policy_choice
# 0              0
# 1              0
# 2              1
# 3              0
# 4              1

# %%
# %Rpush long_df

# %%
# %%R
#
# # check is pre-believe moderate the effect of Condition
# model <- glmer(Policy_choice ~ C(Condition) * C(believer_81) + (1 | PROLIFIC_PID) + (1 | Policy_item),
#                data = long_df, family = binomial)
#
# print(summary(model))
# summary_model <- summary(model)
#
# cohens_d <- lme.dscore(model, data = long_df, type = "lme4")
# print(cohens_d)
#
# confint_model <- confint(model, method = "Wald")
# print(confint_model)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: Policy_choice ~ C(Condition) * C(believer_81) + (1 | PROLIFIC_PID) +
#     (1 | Policy_item)
#    Data: long_df
#
#      AIC      BIC   logLik deviance df.resid
#   8553.4   8622.2  -4266.7   8533.4     7215
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.2619 -0.7560  0.3843  0.6328  1.9712
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  PROLIFIC_PID (Intercept) 0.9430   0.9711
#  Policy_item  (Intercept) 0.2511   0.5011
# Number of obs: 7225, groups:  PROLIFIC_PID, 1445; Policy_item, 5
#
# Fixed effects:
#                               Estimate Std. Error z value Pr(>|z|)
# (Intercept)                    -0.3072     0.2478  -1.240 0.215127
# C(Condition)1                   0.2475     0.1479   1.673 0.094355 .
# C(Condition)2                   0.3532     0.1493   2.366 0.017979 *
# C(Condition)3                   0.5629     0.1486   3.788 0.000152 ***
# C(believer_81)1                 1.1763     0.1500   7.844 4.37e-15 ***
# C(Condition)1:C(believer_81)1   0.2220     0.2122   1.046 0.295455
# C(Condition)2:C(believer_81)1   0.2667     0.2147   1.242 0.214204
# C(Condition)3:C(believer_81)1   0.2439     0.2155   1.132 0.257773
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) C(Cn)1 C(Cn)2 C(Cn)3 C(_81) C(C)1: C(C)2:
# C(Conditn)1 -0.305
# C(Conditn)2 -0.303  0.506
# C(Conditn)3 -0.304  0.509  0.505
# C(blvr_81)1 -0.302  0.506  0.502  0.506
# C(C)1:C(_81  0.212 -0.697 -0.352 -0.354 -0.699
# C(C)2:C(_81  0.210 -0.352 -0.694 -0.350 -0.690  0.489
# C(C)3:C(_81  0.209 -0.350 -0.347 -0.688 -0.687  0.487  0.482
# optimizer (Nelder_Mead) convergence code: 0 (OK)
# Model failed to converge with max|grad| = 0.101668 (tol = 0.002, component 1)
#
#                                       t   df          d
# C(Condition)1                 1.7007844 1437 0.08973272
# C(Condition)2                 2.4233737 1437 0.12785625
# C(Condition)3                 3.9550146 1437 0.20866502
# C(believer_81)1               8.1384230 1437 0.42938001
# C(Condition)1:C(believer_81)1 0.8490440 1437 0.04479523
# C(Condition)2:C(believer_81)1 0.8864483 1437 0.04676867
# C(Condition)3:C(believer_81)1 0.4871709 1437 0.02570294
#                                     2.5 %    97.5 %
# .sig01                                 NA        NA
# .sig02                                 NA        NA
# (Intercept)                   -0.79300084 0.1785427
# C(Condition)1                 -0.04247008 0.5373890
# C(Condition)2                  0.06062417 0.6458130
# C(Condition)3                  0.27164887 0.8542392
# C(believer_81)1                0.88237585 1.4702241
# C(Condition)1:C(believer_81)1 -0.19391799 0.6379927
# C(Condition)2:C(believer_81)1 -0.15412784 0.6874791
# C(Condition)3:C(believer_81)1 -0.17852669 0.6663569
# In addition: Warning message:
# In checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv,  :
#   Model failed to converge with max|grad| = 0.101668 (tol = 0.002, component 1)

# %% [markdown]
# # Examing the moderating effect of political affiliation

# %%
# convert wide to long format adding political affiliation
long_df = df.melt(id_vars=['PROLIFIC_PID', 'Condition', 'Politics'],
                  value_vars=['Policy_choice_1', 'Policy_choice_2', 'Policy_choice_3', 'Policy_choice_4', 'Policy_choice_5'],
                  var_name='Policy_item',
                  value_name='Policy_choice')

long_df.head()
# Out:
#                PROLIFIC_PID  Condition  Politics      Policy_item  \
# 0  55678ac4fdf99b02081d82c2          0         0  Policy_choice_1
# 1  558ab509fdf99b65685f024e          2         0  Policy_choice_1
# 2  559e6830fdf99b4f0b98514a          1         1  Policy_choice_1
# 3  5622e4dced6e5a0005c80078          0         0  Policy_choice_1
# 4  56a914f0119265000c6e13c5          2         0  Policy_choice_1
#
#    Policy_choice
# 0              0
# 1              0
# 2              1
# 3              0
# 4              1

# %%
# %Rpush long_df

# %%
# %%R
#
# # check is party affiliation moderate the effect of Condition
# model <- glmer(Policy_choice ~ C(Condition) * C(Politics) + (1 | PROLIFIC_PID) + (1 | Policy_item),
#                data = long_df, family = binomial)
#
# print(summary(model))
# summary_model <- summary(model)
#
# cohens_d <- lme.dscore(model, data = long_df, type = "lme4")
# print(cohens_d)
#
# confint_model <- confint(model, method = "Wald")
# print(confint_model)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: Policy_choice ~ C(Condition) * C(Politics) + (1 | PROLIFIC_PID) +
#     (1 | Policy_item)
#    Data: long_df
#
#      AIC      BIC   logLik deviance df.resid
#   8780.5   8876.9  -4376.2   8752.5     7211
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.0469 -0.7683  0.4227  0.6307  1.8650
#
# Random effects:
#  Groups       Name        Variance Std.Dev.
#  PROLIFIC_PID (Intercept) 1.263    1.124
#  Policy_item  (Intercept) 0.253    0.503
# Number of obs: 7225, groups:  PROLIFIC_PID, 1445; Policy_item, 5
#
# Fixed effects:
#                            Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 0.61379    0.25966   2.364 0.018085 *
# C(Condition)1               0.54352    0.18603   2.922 0.003481 **
# C(Condition)2               0.62001    0.18351   3.379 0.000729 ***
# C(Condition)3               0.85869    0.18820   4.563 5.05e-06 ***
# C(Politics)1               -0.46423    0.17441  -2.662 0.007775 **
# C(Politics)2               -0.67422    0.24990  -2.698 0.006977 **
# C(Condition)1:C(Politics)1 -0.30042    0.24918  -1.206 0.227964
# C(Condition)2:C(Politics)1 -0.35657    0.25142  -1.418 0.156120
# C(Condition)3:C(Politics)1 -0.29016    0.25237  -1.150 0.250253
# C(Condition)1:C(Politics)2 -0.34119    0.34690  -0.984 0.325343
# C(Condition)2:C(Politics)2 -0.02343    0.34521  -0.068 0.945889
# C(Condition)3:C(Politics)2 -0.36070    0.35046  -1.029 0.303371
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) C(Cn)1 C(Cn)2 C(Cn)3 C(Pl)1 C(Pl)2 C(C)1:C(P)1 C(C)2:C(P)1
# C(Conditn)1 -0.346
# C(Conditn)2 -0.351  0.492
# C(Conditn)3 -0.341  0.481  0.488
# C(Politcs)1 -0.371  0.515  0.522  0.508
# C(Politcs)2 -0.259  0.359  0.364  0.355  0.385
# C(C)1:C(P)1  0.259 -0.746 -0.367 -0.358 -0.699 -0.269
# C(C)2:C(P)1  0.256 -0.359 -0.729 -0.355 -0.692 -0.266  0.485
# C(C)3:C(P)1  0.256 -0.357 -0.362 -0.744 -0.690 -0.265  0.483       0.479
# C(C)1:C(P)2  0.186 -0.536 -0.264 -0.257 -0.277 -0.719  0.400       0.192
# C(C)2:C(P)2  0.187 -0.261 -0.531 -0.258 -0.278 -0.723  0.195       0.387
# C(C)3:C(P)2  0.184 -0.258 -0.262 -0.536 -0.274 -0.712  0.192       0.191
#             C(C)3:C(P)1 C(C)1:C(P)2 C(C)2:C(P)2
# C(Conditn)1
# C(Conditn)2
# C(Conditn)3
# C(Politcs)1
# C(Politcs)2
# C(C)1:C(P)1
# C(C)2:C(P)1
# C(C)3:C(P)1
# C(C)1:C(P)2  0.191
# C(C)2:C(P)2  0.192       0.521
# C(C)3:C(P)2  0.400       0.514       0.516
# optimizer (Nelder_Mead) convergence code: 0 (OK)
# Model failed to converge with max|grad| = 0.0269101 (tol = 0.002, component 1)
#
#                                      t       df           d
# C(Condition)1               2.81430472 1432.999  0.14868878
# C(Condition)2               3.20134881 1432.999  0.16913756
# C(Condition)3               4.23313494 1432.999  0.22365015
# C(Politics)1               -2.67638515 1432.999 -0.14140204
# C(Politics)2               -2.69383990 1432.999 -0.14232423
# C(Condition)1:C(Politics)1 -1.10058939 1432.999 -0.05814768
# C(Condition)2:C(Politics)1 -1.30192329 1432.999 -0.06878480
# C(Condition)3:C(Politics)1 -0.87958638 1432.999 -0.04647138
# C(Condition)1:C(Politics)2 -0.88604755 1432.999 -0.04681274
# C(Condition)2:C(Politics)2  0.07725102 1432.999  0.00408142
# C(Condition)3:C(Politics)2 -0.75975214 1432.999 -0.04014015
#                                 2.5 %     97.5 %
# .sig01                             NA         NA
# .sig02                             NA         NA
# (Intercept)                 0.1048760  1.1227071
# C(Condition)1               0.1789123  0.9081189
# C(Condition)2               0.2603360  0.9796922
# C(Condition)3               0.4898189  1.2275626
# C(Politics)1               -0.8060712 -0.1223902
# C(Politics)2               -1.1640174 -0.1844244
# C(Condition)1:C(Politics)1 -0.7888017  0.1879675
# C(Condition)2:C(Politics)1 -0.8493429  0.1361986
# C(Condition)3:C(Politics)1 -0.7847871  0.2044754
# C(Condition)1:C(Politics)2 -1.0211095  0.3387256
# C(Condition)2:C(Politics)2 -0.7000384  0.6531786
# C(Condition)3:C(Politics)2 -1.0475827  0.3261808
# In addition: Warning message:
# In checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv,  :
#   Model failed to converge with max|grad| = 0.0269101 (tol = 0.002, component 1)
